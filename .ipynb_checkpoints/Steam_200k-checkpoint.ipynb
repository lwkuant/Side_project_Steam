# %% [markdown]
# # Introduction

# %% [markdown]
# Conducting a quick analysis on this dataset to get an overview of what are the trends, relationships and some inspirations, which can give us some directions on the further analysis when have more data.

# %% [markdown]
# ## Setup

# %%
## load the required packages
import numpy as np
import scipy as sp 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
## load the dataset
df = pd.read_csv('D:/Dataset/Side_project_Steam/steam-200k.csv', header=None, encoding='utf-8')

print(df.shape)
print(df.head())

## assign the column names 
col_name = ['User', 'Game', 'Behavior', 'Behavior_value', 'Other']
df.columns = col_name
print()
print(df.head())
print(df.info())
# Out:
# (200000, 5)
#            0                           1         2      3  4
# 0  151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 1  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 2  151603712                   Fallout 4  purchase    1.0  0
# 3  151603712                   Fallout 4      play   87.0  0
# 4  151603712                       Spore  purchase    1.0  0
#         User                        Game  Behavior  Behavior_value  Other
# 0  151603712  The Elder Scrolls V Skyrim  purchase             1.0      0
# 1  151603712  The Elder Scrolls V Skyrim      play           273.0      0
# 2  151603712                   Fallout 4  purchase             1.0      0
# 3  151603712                   Fallout 4      play            87.0      0
# 4  151603712                       Spore  purchase             1.0      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 5 columns):
# User              200000 non-null int64
# Game              200000 non-null object
# Behavior          200000 non-null object
# Behavior_value    200000 non-null float64
# Other             200000 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 7.6+ MB
# None

# %%
## overview of the dataset 

# check if there are NAs
print('Number of NAs:')
print(np.sum(df.isnull()))

# chek if there are multiple vales for the column "Other"
print()
print(df['Other'].value_counts()) # since there are no various values for column "Other", I can remove this column

# remove the column "Other"
df.drop(['Other'], axis=1, inplace=True)
print()
print(df.columns)
# Out:
# Number of NAs:
# User              0
# Game              0
# Behavior          0
# Behavior_value    0
# Other             0
# dtype: int64
# 0    200000
# Name: Other, dtype: int64
# Index(['User', 'Game', 'Behavior', 'Behavior_value'], dtype='object')

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Has each game purchased by users been played?

# %%
# group by user and game to test
group_user_game = df.groupby(['User', 'Game'])
print(group_user_game['Game'].count().value_counts())
# Out:
# 2    70616
# 1    57904
# 3      272
# 4       12
# Name: Game, dtype: int64

# %% [markdown]
#  If the value is 1, it means the game is not played by the user. However, how about the 3 and 4? Let's check!

# %%
# check the 3 and 4 in the grouped table
print(group_user_game['Game'].count()[group_user_game['Game'].count().isin([3, 4])].head(10)) # take some examples

# display one example (for 3)
print()
print("for 3")
print(df.ix[(df['User'] == 1936551)&(df['Game'] == "Sid Meier's Civilization IV Colonization"), :])

# display one example (for 4)
print()
print("for 4")
print(df.ix[(df['User'] == 176261926)&(df['Game'] == "Sid Meier's Civilization IV"), :])

# extract the games in 3 and 4 group
print()
odd_games = [name[1] for name in list(dict(group_user_game['Game'].count()[group_user_game['Game'].count().isin([3, 4])]).keys())]
print(np.unique(odd_games))

print()
print('There are', len(np.unique(df['Game'])), 'Games')
# Out:
# User     Game
# 1936551  Sid Meier's Civilization IV Colonization    3
# 2259650  Sid Meier's Civilization IV                 3
#          Sid Meier's Civilization IV Colonization    3
#          Sid Meier's Civilization IV Warlords        3
# 4824107  Grand Theft Auto San Andreas                3
# 6717871  Crysis 2                                    3
# 6928806  Grand Theft Auto San Andreas                3
#          Sid Meier's Civilization IV                 3
# 8259307  Grand Theft Auto III                        3
#          Grand Theft Auto San Andreas                3
# Name: Game, dtype: int64
#
# for 3
#           User                                      Game  Behavior  \
# 89867  1936551  Sid Meier's Civilization IV Colonization  purchase
# 89868  1936551  Sid Meier's Civilization IV Colonization      play
# 90025  1936551  Sid Meier's Civilization IV Colonization  purchase
#
#        Behavior_value
# 89867             1.0
# 89868             7.4
# 90025             1.0
#
# for 4
#              User                         Game  Behavior  Behavior_value
# 186770  176261926  Sid Meier's Civilization IV  purchase             1.0
# 186771  176261926  Sid Meier's Civilization IV      play            14.6
# 186780  176261926  Sid Meier's Civilization IV  purchase             1.0
# 186781  176261926  Sid Meier's Civilization IV      play             0.2
#
# ['Crysis 2' 'Grand Theft Auto III' 'Grand Theft Auto San Andreas'
#  'Grand Theft Auto Vice City' "Sid Meier's Civilization IV"
#  "Sid Meier's Civilization IV Beyond the Sword"
#  "Sid Meier's Civilization IV Colonization"
#  "Sid Meier's Civilization IV Warlords" "Tom Clancy's H.A.W.X. 2"]
#
# There are 5155 Games

# %% [markdown]
# From the observations, I find that the 3 and 4 behaviors in some cases indicate that certain games had been purchased again by the user. And I also find that this phenomenon happens on only specific games

# %%
# display some examples
print(group_user_game['Game'].count()[group_user_game['Game'].count().isin([1])].head(10))

# get the games' names
from collections import defaultdict
aban_games_dict = defaultdict(int)

# calculate the frequencies
for game in list(dict(group_user_game['Game'].count()[group_user_game['Game'].count().isin([1])]).keys()):
    aban_games_dict[game[1]] += 1

purchase_games_dict = defaultdict(int)

for game in list(dict(group_user_game['Game'].count()[group_user_game['Game'].count().isin([1, 2])]).keys()):
    purchase_games_dict[game[1]] += 1

ratio_dict = {}

for game in list(aban_games_dict.keys()):
    ratio_dict[game] = aban_games_dict[game]/purchase_games_dict[game]

aban_games_df = pd.Series(ratio_dict)
#print(aban_games_df.sort_values(ascending=False))

aban_games_df = pd.DataFrame(aban_games_df, columns=['Adandon_ratio'], index=list(aban_games_df.index))

purchase_list = []
for game in list(aban_games_df.index):
    purchase_list.append(purchase_games_dict[game])

aban_games_df['Purchase_times'] = purchase_list

print(aban_games_df.sort_values(by='Adandon_ratio', ascending=False))
# Out:
# User  Game
# 5250  Counter-Strike             1
#       Counter-Strike Source      1
#       Day of Defeat              1
#       Deathmatch Classic         1
#       Half-Life                  1
#       Half-Life 2                1
#       Half-Life 2 Deathmatch     1
#       Half-Life 2 Episode One    1
#       Half-Life 2 Episode Two    1
#       Half-Life 2 Lost Coast     1
# Name: Game, dtype: int64
#                                                     Adandon_ratio  \
# Radial Impact                                            1.000000
# Flotilla                                                 1.000000
# FortressCraft Evolved Multiplayer                        1.000000
# SoulCraft                                                1.000000
# Fortress Forever                                         1.000000
# Soulbringer                                              1.000000
# Fort Defense                                             1.000000
# Soundodger+                                              1.000000
# Foresight                                                1.000000
# For The Glory                                            1.000000
# Football Manager 2016 Touch Mode - Design a Son          1.000000
# South Park The Stick of Truth - Super Samurai S...       1.000000
# South Park The Stick of Truth - Ultimate Fellow...       1.000000
# Pitiri 1977                                              1.000000
# Pixel Boy and the Ever Expanding Dungeon                 1.000000
#                                                     Purchase_times
# Skyrim High Resolution Texture Pack                            235
# The Elder Scrolls V Skyrim - Dragonborn                        365
# Borderlands DLC Mad Moxxi's Underdome Riot                     135
# Sid Meier's Civilization V Brave New World                     241
# Sid Meier's Civilization V Scrambled Continents...             139
# Magicka Vietnam                                                109
# Borderlands DLC The Secret Armory of General Knoxx             138
# Borderlands DLC The Zombie Island of Dr. Ned                   139
# Borderlands DLC Claptraps New Robot Revolution                 128
# The Elder Scrolls V Skyrim - Dawnguard                         378
# Arma 3 Zeus                                                    161
# Fallout New Vegas Courier's Stash                              188
# The Elder Scrolls V Skyrim - Hearthfire                        367
# Fallout New Vegas Dead Money                                   202
# Medal of Honor Pre-Order                                       113
# Fallout New Vegas Honest Hearts                                202
# Age of Empires II HD The Forgotten                             115
# Ricochet                                                       524
# Patch testing for Chivalry                                     222
# Half-Life Deathmatch Source                                    268
# Deathmatch Classic                                             524
# H1Z1 Test Server                                               138
# Team Fortress Classic                                          366
# Starbound - Unstable                                           134
# Half-Life Opposing Force                                       366
# Arma 2 Operation Arrowhead Beta (Obsolete)                     250
# Half-Life Blue Shift                                           363
# Killing Floor Mod Defence Alliance 2                           213
# Counter-Strike Condition Zero Deleted Scenes                   679
# Company of Heroes Opposing Fronts                              144
# ...                                                            ...
# Call of Duty Black Ops                                         254
# Call of Duty Black Ops II - Multiplayer                        168
# Borderlands 2                                                  429
# The Stanley Parable                                            110
# Total War SHOGUN 2                                             198
# The Walking Dead                                               122
# Torchlight II                                                  224
# Garry's Mod                                                    731
# PAYDAY 2                                                       427
# Euro Truck Simulator 2                                         187
# Total War ROME II - Emperor Edition                            166
# Battlefield Bad Company 2                                      120
# South Park The Stick of Truth                                  107
# Terraria                                                       496
# Sid Meier's Civilization V                                     596
# Space Engineers                                                109
# Cities Skylines                                                122
# The Elder Scrolls V Skyrim                                     717
# Rocket League                                                  157
# 7 Days to Die                                                  103
# Rust                                                           214
# ARK Survival Evolved                                           163
# Arma 3                                                         161
# Counter-Strike Global Offensive                               1412
# The Forest                                                     131
# Starbound                                                      134
# Grand Theft Auto V                                             273
# DayZ                                                           249
# H1Z1                                                           138
# Fallout 4                                                      168
#
# [242 rows x 2 columns]

# %% [markdown]
# There are many games that were purchased by many users; however, they had not been played. It sounds werid to me, I think I need more data to validate this phenomenon, like the release date or if there are played on other platforms thus they couldn't be tracked.

# %% [markdown]
# ## The most-played games!

# %%
# get the times played
played_games_dict = defaultdict(int)

for game in list(dict(group_user_game['Game'].count()[group_user_game['Game'].count().isin([2])]).keys()):
    played_games_dict[game[1]] += 1
    
# get the hours played
played_time = df.ix[(df['Game'].isin(list(played_games_dict.keys())))&(df['Behavior'] == 'play'), :].groupby(['Game'])
#print(played_time['Behavior_value'].sum())

play_df = pd.Series(dict(played_time['Behavior_value'].sum()))
play_df = pd.DataFrame(play_df, columns=['Time_played'], index=list(play_df.index))

play_list = []
for game in list(play_df.index):
    play_list.append(played_games_dict[game])

play_df['User_num'] = play_list

play_df['Avg_play_time'] = play_df['Time_played']/play_df['User_num']
print(play_df.sort_values(by=['Avg_play_time'], ascending=False).head(10))
# Out:
#                                    Time_played  User_num  Avg_play_time
# Eastside Hockey Manager                 1295.0         1    1295.000000
# Baldur's Gate II Enhanced Edition       4277.3         9     475.255556
# FIFA Manager 09                          411.0         1     411.000000
# Perpetuum                               1603.9         4     400.975000
# Football Manager 2014                  30574.8        78     391.984615
# Football Manager 2012                  30845.8        79     390.453165
# Football Manager 2010                  13126.7        35     375.048571
# Football Manager 2011                  11336.8        31     365.703226
# Freaking Meatbags                        331.0         1     331.000000
# Out of the Park Baseball 16              660.8         2     330.400000

# %%
## the distribution of number of users playing each game

num_users_list = play_df['User_num'].values

print(np.max(num_users_list))

fig, axes = plt.subplots(figsize=[5, 5])
sns.boxplot(data = num_users_list)
axes.set_title('The Distribution of Number of Users Playing Each Game')

print(np.percentile(num_users_list, q=[25, 50, 75]))
# Out:
# 4841
# [  1.   4.  12.]

# %% [markdown]
# The numbers of users of each game are very right-skewed, which means almost of the users only purchase and play few games.

# %%
## The most-played games by total hours played
print(play_df.sort_values(by=['Time_played'], ascending=False).head())

play_df.sort_values(by=['Time_played'], ascending=True)[-10:]['Time_played'].plot.barh(color='#2E8B57', edgecolor='none')
plt.title('Top 10 Most-Played Games (by total time played)', fontsize=15)
plt.xlabel('Time played (in hours)')
# Out:
#                                  Time_played  User_num  Avg_play_time
# Dota 2                              981684.6      4841     202.785499
# Counter-Strike Global Offensive     322771.6      1377     234.402033
# Team Fortress 2                     173673.3      2323      74.762505
# Counter-Strike                      134261.1       568     236.375176
# Sid Meier's Civilization V           99821.3       554     180.182852

# %%
## The most-played games by number of users playing 
print(play_df.sort_values(by=['User_num'], ascending=False).head())

play_df.sort_values(by=['User_num'], ascending=True)[-10:]['User_num'].plot.barh(color='#2E8B57', edgecolor='none')
plt.title('Top 10 Most-Played Games (by number of users playing)', fontsize=15)
plt.xlabel('Number of users playing')
# Out:
#                                  Time_played  User_num  Avg_play_time
# Dota 2                              981684.6      4841     202.785499
# Team Fortress 2                     173673.3      2323      74.762505
# Counter-Strike Global Offensive     322771.6      1377     234.402033
# Unturned                             16096.4      1069      15.057437
# Left 4 Dead 2                        33596.7       801      41.943446

# %%
## The most-played games by average of hours played and meeting certain number of users 
print(play_df.sort_values(by=['Avg_play_time'], ascending=False).head())

# use 100 as the criteria for hotness
play_df.ix[play_df['User_num']>100, :].sort_values(by=['Avg_play_time'], ascending=True)[-10:]['Avg_play_time'].plot.barh(color='#2E8B57', edgecolor='none')
plt.title('Top 10 Most-Played Games (by average time played)', fontsize=15)
plt.xlabel('Average time played (in hours)')
# Out:
#                                    Time_played  User_num  Avg_play_time
# Eastside Hockey Manager                 1295.0         1    1295.000000
# Baldur's Gate II Enhanced Edition       4277.3         9     475.255556
# FIFA Manager 09                          411.0         1     411.000000
# Perpetuum                               1603.9         4     400.975000
# Football Manager 2014                  30574.8        78     391.984615

# %% [markdown]
# ## Further research

# %% [markdown]
# If we have more data, such as the time of purchasing, the genre of each games, ratings and so on, we would be able to do more insightful analysis. For example, the types of purchasing behavior, the relatioinship between each game and recommender system based on this data are all great starting points!
